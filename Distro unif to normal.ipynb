# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
## Pregunta 1

# %%
def generador_muestra(a, b, n):
    if a < b:
        muestra = np.random.uniform(a, b, n)
    else:
        muestra = np.random.uniform(a, b, n)
    #print (muestra)
    #historigrama(s)
    return muestra

# %%
def historigrama(s):
    count, bins, ignored = plt.hist(s, 'auto', density=True)
    plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')
    plt.title("Muestra de distribución uniforme")
    plt.ylabel('frequencia')
    plt.xlabel('valores')
    plt.show()

# %%
def prueba_normalidad(s, alpha=0.05):
    D, pval = ss.kstest(s, 'norm')
    print(D, pval)
    
    if pval < alpha:
        print('rechazado')
        return False
    
    else:
        print('aceptado')
        return True

# %%
muestra = generador_muestra( 1, 10, 100 )
historigrama(muestra)
prueba_normalidad(muestra, 0.05)
# Out:
# 0.8972078155946072 3.250574976249411e-99
# rechazado
# False

# %%
a, b, n = list(map(int,input("Ingrese a, b y n").split()))
muestra = generador_muestra( a, b, n )
historigrama(muestra)
prueba_normalidad(muestra, 0.05)
# Out:
# Ingrese a, b y n1 10 100
# rechazado
# False

# %%
# Pregunta 2

# %%
def agregar_valores(s, alpha=0.05, n=None):
    if n == None:
        n = int(len(s)/2)
        
    while True:
        if prueba_normalidad(s, alpha=alpha) == False:
            
            s = np.append( s, np.random.normal(s.mean(), s.std(), n) )
            print(len(s))
            historigrama(s)
        else:
            break
            
    print(prueba_normalidad(s, alpha=alpha))
    print(f"Tamaño de la muestra: {len(s)}")
    
    return s

# %%
print(len(muestra))
muestra = agregar_valores(muestra)
# Out:
# 100
# 0.8972078155946072 3.250574976249411e-99
# rechazado
# 150
# 0.8738744822612738 3.578428961975914e-135
# rechazado
# 200
# 0.863382481075287 5.135508540356276e-173
# rechazado
# 250
# 0.858382481075287 3.6878484656331685e-212
# rechazado
# 300
# 0.8524487961140577 5.342857272836971e-249
# rechazado
# 350
# 0.8564283014968614 1.0621539897951129e-294
# rechazado
# 400
# 0.8598829451071176 0.0
# rechazado
# 450
# 0.8643648094333695 0.0
# rechazado
# 500
# 0.8623186884061144 0.0
# rechazado
# 550
# 0.8625005065879325 0.0
# rechazado
# 600
# 0.8662954039684905 0.0
# rechazado
# 650
# 0.8700133526864393 0.0
# rechazado
# 700
# 0.8732001658732524 0.0
# rechazado
# 750
# 0.8727838759028077 0.0
# rechazado
# 800
# 0.8752838759028077 0.0
# rechazado
# 850
# 0.8754732263838262 0.0
# rechazado
# 900
# 0.8760614616779439 0.0
# rechazado
# 950
# 0.8734298827305754 0.0
# rechazado
# 1000
# 0.8700627233273934 0.0
# rechazado
# 1050
# 0.8729277530173833 0.0
# rechazado
# 1100
# ...

# %% [markdown]
# ![vigilante.jpeg](attachment:vigilante.jpeg)
